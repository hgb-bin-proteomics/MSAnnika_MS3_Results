# %%
import pandas as pd
from venn import venn

# replicate 1
rep1_maxlinker = pd.read_csv("rep1/MaXLinker_20220215_Eclipse_LC6_PepMap50cm-cartridge_mainlib_DSSO_CV55_MS3_OT_001_20220215181437_crap_out_gbSeqPos_output.csv")
rep1_ms2annika = pd.read_csv("rep1/MS2Annika_20220215_Eclipse_LC6_PepMap50cm-cartridge_mainlib_DSSO_CV55_MS3_OT_001_20220215181437-(3)_output.csv")
rep1_ms3annika = pd.read_csv("rep1/MS3Annika_20220215_Eclipse_LC6_PepMap50cm-cartridge_mainlib_DSSO_CV55_MS3_OT_001_20220215181437-(1)_output.csv")
rep1_xlinkx = pd.read_csv("rep1/XlinkX_20220215_Eclipse_LC6_PepMap50cm-cartridge_mainlib_DSSO_CV55_MS3_OT_001_20220215181437-(2)_output.csv")

# replicate 2
rep2_maxlinker = pd.read_csv("rep2/MaXLinker_20220215_Eclipse_LC6_PepMap50cm-cartridge_mainlib_DSSO_CV55_MS3_OT_002_crap_out_gbSeqPos_output.csv")
rep2_ms2annika = pd.read_csv("rep2/MS2Annika_20220215_Eclipse_LC6_PepMap50cm-cartridge_mainlib_DSSO_CV55_MS3_OT_002-(3)_output.csv")
rep2_ms3annika = pd.read_csv("rep2/MS3Annika_20220215_Eclipse_LC6_PepMap50cm-cartridge_mainlib_DSSO_CV55_MS3_OT_002-(1)_output.csv")
rep2_xlinkx = pd.read_csv("rep2/XlinkX_20220215_Eclipse_LC6_PepMap50cm-cartridge_mainlib_DSSO_CV55_MS3_OT_002-(1)_output.csv")

# replicate 3
rep3_maxlinker = pd.read_csv("rep3/MaXLinker_20220215_Eclipse_LC6_PepMap50cm-cartridge_mainlib_DSSO_CV55_MS3_OT_003_crap_out_gbSeqPos_output.csv")
rep3_ms2annika = pd.read_csv("rep3/MS2Annika_20220215_Eclipse_LC6_PepMap50cm-cartridge_mainlib_DSSO_CV55_MS3_OT_003-(3)_output.csv")
rep3_ms3annika = pd.read_csv("rep3/MS3Annika_20220215_Eclipse_LC6_PepMap50cm-cartridge_mainlib_DSSO_CV55_MS3_OT_003-(1)_output.csv")
rep3_xlinkx = pd.read_csv("rep3/XlinkX_20220215_Eclipse_LC6_PepMap50cm-cartridge_mainlib_DSSO_CV55_MS3_OT_003-(1)_output.csv")

# %%
def get_crosslink(dataset_row):
    seq_a = dataset_row["Sequence A"]
    seq_b = dataset_row["Sequence B"]
    
    return "-".join(sorted([seq_a, seq_b]))

# %%
rep1_maxlinker_xls = set(rep1_maxlinker.loc[rep1_maxlinker["Within same group"]].apply(lambda row: get_crosslink(row), axis = 1))
rep1_ms2annika_xls = set(rep1_ms2annika.loc[rep1_ms2annika["Within same group"]].apply(lambda row: get_crosslink(row), axis = 1))
rep1_ms3annika_xls = set(rep1_ms3annika.loc[rep1_ms3annika["Within same group"]].apply(lambda row: get_crosslink(row), axis = 1))
rep1_xlinkx_xls = set(rep1_xlinkx.loc[rep1_xlinkx["Within same group"]].apply(lambda row: get_crosslink(row), axis = 1))

rep2_maxlinker_xls = set(rep2_maxlinker.loc[rep2_maxlinker["Within same group"]].apply(lambda row: get_crosslink(row), axis = 1))
rep2_ms2annika_xls = set(rep2_ms2annika.loc[rep2_ms2annika["Within same group"]].apply(lambda row: get_crosslink(row), axis = 1))
rep2_ms3annika_xls = set(rep2_ms3annika.loc[rep2_ms3annika["Within same group"]].apply(lambda row: get_crosslink(row), axis = 1))
rep2_xlinkx_xls = set(rep2_xlinkx.loc[rep2_xlinkx["Within same group"]].apply(lambda row: get_crosslink(row), axis = 1))

rep3_maxlinker_xls = set(rep3_maxlinker.loc[rep3_maxlinker["Within same group"]].apply(lambda row: get_crosslink(row), axis = 1))
rep3_ms2annika_xls = set(rep3_ms2annika.loc[rep3_ms2annika["Within same group"]].apply(lambda row: get_crosslink(row), axis = 1))
rep3_ms3annika_xls = set(rep3_ms3annika.loc[rep3_ms3annika["Within same group"]].apply(lambda row: get_crosslink(row), axis = 1))
rep3_xlinkx_xls = set(rep3_xlinkx.loc[rep3_xlinkx["Within same group"]].apply(lambda row: get_crosslink(row), axis = 1))

# %%
# colors
# MaXLinker, MS2 Annika, MS3 Annika, XlinkX
col = ["#4361EE", "#7209B7", "#4CC9F0", "#F72585"]

# %%
venn(rep1_ms3annika_xls, rep2_ms3annika_xls, rep3_ms3annika_xls, labels = ["Replicate 1", "Replicate 2", "Replicate 3"], contour = True, title = "MS Annika 2.0 Replicate Overlap");

# %%
venn(rep1_ms2annika_xls, rep1_ms3annika_xls, labels = ["MS Annika 1.0", "MS Annika 2.0"], colors = [col[1], col[2]], contour = True, title = "Replicate 1");

# %%
venn(rep1_maxlinker_xls, rep1_ms3annika_xls, rep1_xlinkx_xls, labels = ["MaXLinker", "MS Annika 2.0", "XlinkX"], contour = True, title = "Replicate 1");

# %%
venn(rep2_ms2annika_xls, rep2_ms3annika_xls, labels = ["MS Annika 1.0", "MS Annika 2.0"], colors = [col[1], col[2]], contour = True, title = "Replicate 2");

# %%
venn(rep2_maxlinker_xls, rep2_ms3annika_xls, rep2_xlinkx_xls, labels = ["MaXLinker", "MS Annika 2.0", "XlinkX"], contour = True, title = "Replicate 2");

# %%
venn(rep3_ms2annika_xls, rep3_ms3annika_xls, labels = ["MS Annika 1.0", "MS Annika 2.0"], colors = [col[1], col[2]], contour = True, title = "Replicate 3");

# %%
venn(rep3_maxlinker_xls, rep3_ms3annika_xls, rep3_xlinkx_xls, labels = ["MaXLinker", "MS Annika 2.0", "XlinkX"], contour = True, title = "Replicate 3");
